# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller
import yfinance as yf

# %%
import yfinance as yf
start_date = '2018-01-01'
data = yf.download('TSLA', start = start_date)
data['Adj Close'].plot(figsize=(12,8))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %%
# ADF Test
adf_result= adfuller(data['Adj Close'])
print('ADF Statistic: %f' % adf_result[0])
print('p-value: %f' % adf_result[1])
# Out:
# ADF Statistic: -1.407508
# p-value: 0.578671

# %%
#Daily Return
data['returns'] = data['Adj Close'].pct_change()
data.dropna(inplace=True)
data['returns'].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
# ADF Test
adf_result= adfuller(data['returns'])
print('ADF Statistic: %f' % adf_result[0])
print('p-value: %f' % adf_result[1])
# Out:
# ADF Statistic: -39.141551
# p-value: 0.000000
